# %%
import os
if os.path.basename(os.getcwd()) == "inspeccion":
    os.chdir("..")
    
import pandas as pd
from utils.funciones_filtrado import tipo_nulo_unicos_x_columna

# %%
base_campanas = pd.read_excel('campanas.xlsx')
base_campanas.head()
# Out:
#            campaña fecha_inicio   fecha_fin           canal  presupuesto  \
# 0  Bienvenida 2024   2024-01-01  2024-01-31  Redes Sociales       5000.0
# 1     San Valentín   2024-02-01  2024-02-15           Email       3000.0
# 2    Café de Marzo   2024-03-01  2024-03-31  redes sociales       4500.0
# 3        Primavera   2024-03-15  2024-04-15           Flyer          NaN
# 4     Día del Niño   2024-04-20  2024-04-30  Redes Sociales       2000.0
#
#         sucursal  ventas_generadas
# 0  Puebla Centro           85000.0
# 1  Puebla centro               NaN
# 2    Angelópolis           72000.0
# 3    ANGELOPOLIS           61000.0
# 4        Cholula           38000.0

# %%
no_registros, no_columnas = base_campanas.shape
print(f"Número de productos registrados: {no_registros}, número de columnas de la tabla: {no_columnas}")
# Out:
# Número de productos registrados: 11, número de columnas de la tabla: 7

# %% [markdown]
# Podemos notar rapidamente algunas inconsistencias en los datos, en la columna 'canal' existe una diferencia entre 'Redes' y 'redes', esto nos puede provocar errores al realizar analisis, lo que nos hace sospechar que otros registros de esa columna también tengan ese problema. De manera similar la columna 'sucursal' tiene el problema de 'ANGELOPOLIS' y 'Angelópolis'.
#
# Adicionalmente las columnas 'prespuesto' y 'ventas_generadas' contienen valores nulos, que al estudiar los desempeños de las campañas nos puede afectar.

# %%
inspeccion = tipo_nulo_unicos_x_columna(base_campanas)
inspeccion
# Out:
#             columna tipo de dato  cantidad de valores nulos  \
# 0           campaña       object                          0
# 1      fecha_inicio       object                          0
# 2         fecha_fin       object                          0
# 3             canal       object                          0
# 4       presupuesto      float64                          2
# 5          sucursal       object                          0
# 6  ventas_generadas      float64                          1
#
#    cantidad de valores unicos
# 0                          11
# 1                          11
# 2                          10
# 3                           4
# 4                           9
# 5                           8
# 6                          10

# %% [markdown]
# Las columnas si están en el tipo que uno esperaría como la de 'presupuesto' y 'ventas_generadas' están en tipo numérico, pero sólo faltaría convertir las columnas a tipo fecha.
#
# Adicionalmente notamos que efectivamente las únicas columnas con valores nulos son las de 'presupuesto' y 'ventas_generadas', como se pudo ver en la inspección rápida, además observamos que en la 'fecha_fin' hay 2 fechas que coinciden en el termino, pero eso no nos generará una preocupación por el momento

# %%
base_campanas['canal'].unique()
# Out:
# array(['Redes Sociales', 'Email', 'redes sociales', 'Flyer'], dtype=object)

# %% [markdown]
# Verificamos que ningún otro método de publicación de campaña esté mal escrito, y notamos que sólo está mal escrito el canal de 'redes sociales'

# %%
base_campanas['sucursal'].unique()
# Out:
# array(['Puebla Centro', 'Puebla centro', 'Angelópolis', 'ANGELOPOLIS',
#        'Cholula', 'Todas', 'Puebla Norte', 'San Andres'], dtype=object)

# %% [markdown]
# De manera similar notamos que aparte de 'Angelopolis' que contienen otro registro mal escrito, está en el 'Puebla Centro', ya que hay al menos otro registro escrito de la manera 'Puebla centro' y tomaremos que la sucursal de Cholula y San Andres son diferentes, ya que hay diversas Cholulas
